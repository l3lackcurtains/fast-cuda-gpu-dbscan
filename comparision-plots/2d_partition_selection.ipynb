# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker

# %%
plt.rcParams.update({'font.size': 14, 'axes.titlesize': 14,'legend.loc': 'upper right', 'legend.fontsize': 11})

fig, axs = plt.subplots(2, 4, figsize=(16, 6), dpi=800)
fig.tight_layout(h_pad=3.0, w_pad=3.0)
fig.patch.set_facecolor('white')
##############################################################################
########################## DATASET SIZE EXPERIMENT
#############################################################################

# NGSIM DATASET
ngsi_partition = [20, 40, 60, 80, 100]
ngsi_1 = [0.24, 0.22, 0.24, 0.27, 0.3]
ngsi_2 = [0.27, 0.23, 0.21, 0.3, 0.36]
ngsi_3 = [0.53, 0.35, 0.32, 0.4, 0.38]
ngsi_4 = [1.42, 0.57, 0.47, 0.43, 0.41]
ngsi_5 = [3.24, 2, 1.87, 1.67, 1.12]

axs[0, 0].plot(ngsi_partition, ngsi_1, label="$|D|$=50000", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[0, 0].plot(ngsi_partition, ngsi_2, label="$|D|$=100000", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[0, 0].plot(ngsi_partition, ngsi_3, label="$|D|$=200000", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[0, 0].plot(ngsi_partition, ngsi_4, label="$|D|$=400000", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
axs[0, 0].plot(ngsi_partition, ngsi_5, label="$|D|$=800000", color='#6ab04c', marker='p',
         linewidth=1, markersize=4, markerfacecolor='#6ab04c')
   
axs[0, 0].set_ylabel("Execution Time (s)")
axs[0, 0].set_xlabel(r'$r$', fontsize=16)
axs[0, 0].set_xscale('linear')
axs[0, 0].set_yscale('log')
axs[0, 0].set_xticks(ngsi_partition)
axs[0, 0].set_ylim(0.1, 100)
axs[0, 0].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[0, 0].set_title("(a) NGSIM")
axs[0, 0].legend();

# SPATIAL DATASET
spatial_partition = [20, 40, 60, 80, 100]
spatial_1 = [0.2, 0.16, 0.19, 0.22, 0.26]
spatial_2 = [0.32, 0.3, 0.3, 0.33, 0.34]
spatial_3 = [0.49, 0.37, 0.37, 0.38, 0.44]
spatial_4 = [0.6, 0.4, 0.39, 0.39, 0.43]
spatial_5 = [0.99, 0.46, 0.38, 0.38, 0.43]

axs[0, 1].plot(spatial_partition, spatial_1, label="$|D|$=25000", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[0, 1].plot(spatial_partition, spatial_2, label="$|D|$=50000", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[0, 1].plot(spatial_partition, spatial_3, label="$|D|$=100000", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[0, 1].plot(spatial_partition, spatial_4, label="$|D|$=200000", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
axs[0, 1].plot(spatial_partition, spatial_5, label="$|D|$=400000", color='#6ab04c', marker='p',
         linewidth=1, markersize=4, markerfacecolor='#6ab04c')
   
axs[0, 1].set_ylabel("Execution Time (s)")
axs[0, 1].set_xlabel(r'$r$', fontsize=16)
axs[0, 1].set_xscale('linear')
axs[0, 1].set_yscale('log')
axs[0, 1].set_xticks(spatial_partition)
axs[0, 1].set_ylim(0.1, 100)
axs[0, 1].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[0, 1].set_title("(b) SPATIAL")
axs[0, 1].legend();

# IONO 2D DATASET
iono2d_partition = [20, 40, 60, 80, 100]
iono2d_1 = [0.25, 0.18, 0.18, 0.19, 0.2]
iono2d_2 = [0.43, 0.36, 0.3, 0.31, 0.34]
iono2d_3 = [0.94, 0.6, 0.47, 0.48, 0.49]
iono2d_4 = [1.68, 0.84, 0.75, 0.6, 0.64]
iono2d_5 = [4.06, 1.51, 0.97, 0.89, 0.85]

axs[0, 2].plot(iono2d_partition, iono2d_1, label="$|D|$=50000", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[0, 2].plot(iono2d_partition, iono2d_2, label="$|D|$=100000", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[0, 2].plot(iono2d_partition, iono2d_3, label="$|D|$=200000", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[0, 2].plot(iono2d_partition, iono2d_4, label="$|D|$=400000", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
axs[0, 2].plot(iono2d_partition, iono2d_5, label="$|D|$=800000", color='#6ab04c', marker='p',
         linewidth=1, markersize=4, markerfacecolor='#6ab04c')
   
axs[0, 2].set_ylabel("Execution Time (s)")
axs[0, 2].set_xlabel(r'$r$', fontsize=16)
axs[0, 2].set_xscale('linear')
axs[0, 2].set_yscale('log')
axs[0, 2].set_xticks(iono2d_partition)
axs[0, 2].set_ylim(0.1, 100)
axs[0, 2].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[0, 2].set_title("(c) IONO")
axs[0, 2].legend();

# PORTO DATASET
porto_partition = [20, 40, 60, 80, 100]
porto_1 = [0.04, 0.03, 0.06, None, None]
porto_2 = [0.13, 0.14, 0.14, 0.16, 0.19]
porto_3 = [0.3, 0.25, 0.18, 0.22, 0.28]
porto_4 = [1.86, 1.1, 1.06, 0.89, 0.89]
porto_5 = [4.31, 3.67, 4.06, 3.45, 3.39]

axs[0, 3].plot(porto_partition, porto_1, label="$|D|$=40000", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[0, 3].plot(porto_partition, porto_2, label="$|D|$=80000", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[0, 3].plot(porto_partition, porto_3, label="$|D|$=160000", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[0, 3].plot(porto_partition, porto_4, label="$|D|$=320000", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
axs[0, 3].plot(porto_partition, porto_5, label="$|D|$=640000", color='#6ab04c', marker='p',
         linewidth=1, markersize=4, markerfacecolor='#6ab04c')
   
axs[0, 3].set_ylabel("Execution Time (s)")
axs[0, 3].set_xlabel(r'$r$', fontsize=16)
axs[0, 3].set_xscale('linear')
axs[0, 3].set_yscale('log')
axs[0, 3].set_xticks(porto_partition)
axs[0, 3].set_ylim(0.1, 1000)
axs[0, 3].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[0, 3].set_title("(d) PORTO")
axs[0, 3].legend();

##############################################################################
########################## EPS EXPERIMENT
#############################################################################

# NGSIM DATASET
ngsi_eps = [20, 40, 60, 80, 100]
ngsi_1 = [4.81, 1.97, 1.43, 1.35, 1.34]
ngsi_2 = [2.73, 1.12, 0.87, 0.85, 0.82]
ngsi_3 = [2.16, 0.81, 0.65, 0.62, 0.6]
ngsi_4 = [1.48, 0.6, 0.48, 0.44, 0.41]
ngsi_5 = [1.15, 0.52, 0.35, 0.34, 0.33]

axs[1, 0].plot(ngsi_eps, ngsi_1, label="ε=0.50", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[1, 0].plot(ngsi_eps, ngsi_2, label="ε=0.75", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[1, 0].plot(ngsi_eps, ngsi_3, label="ε=1.00", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[1, 0].plot(ngsi_eps, ngsi_4, label="ε=1.25", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
axs[1, 0].plot(ngsi_eps, ngsi_5, label="ε=1.50", color='#6ab04c', marker='p',
         linewidth=1, markersize=4, markerfacecolor='#6ab04c')
   
axs[1, 0].set_ylabel("Execution Time (s)")
axs[1, 0].set_xlabel(r'$r$', fontsize=16)
axs[1, 0].set_xscale('linear')
axs[1, 0].set_yscale('log')
axs[1, 0].set_xticks(ngsi_eps)
axs[1, 0].set_ylim(0, 10)
axs[1, 0].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[1, 0].set_title("(e) NGSIM")
axs[1, 0].legend();

# SPATIAL DATASET
spatial_eps = [20, 40, 60, 80, 100]
spatial_1 = [4.52, 2.79, 2.18, 2.02, 1.97]
spatial_2 = [2.97, 1.32, 1.05, 0.98, 1.03]
spatial_3 = [1.56, 0.7, 0.6, 0.58, 0.59]
spatial_4 = [0.84, 0.42, 0.41, 0.4, 0.41]
spatial_5 = [0.66, 0.34, 0.28, 0.29, 0.31]

axs[1, 1].plot(spatial_eps, spatial_1, label="ε=0.002", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[1, 1].plot(spatial_eps, spatial_2, label="ε=0.004", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[1, 1].plot(spatial_eps, spatial_3, label="ε=0.006", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[1, 1].plot(spatial_eps, spatial_4, label="ε=0.008", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
axs[1, 1].plot(spatial_eps, spatial_5, label="ε=0.010", color='#6ab04c', marker='p',
         linewidth=1, markersize=4, markerfacecolor='#6ab04c')
   
axs[1, 1].set_ylabel("Execution Time (s)")
axs[1, 1].set_xlabel(r'$r$', fontsize=16)
axs[1, 1].set_xscale('linear')
axs[1, 1].set_yscale('log')
axs[1, 1].set_xticks(spatial_eps)
axs[1, 1].set_ylim(0.1, 1000)
axs[1, 1].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[1, 1].set_title("(f) SPATIAL")
axs[1, 1].legend()

# IONO 2D DATASET
iono2d_eps = [20, 40, 60, 80, 100]
iono2d_1 = [5.51, 2.25, 1.59, 1.31, 1.28]
iono2d_2 = [3.46, 1.52, 1.13, 0.98, 0.97]
iono2d_3 = [2.36, 1.11, 0.92, 0.84, 0.78]
iono2d_4 = [1.9, 0.96, 0.71, 0.7, 0.73]
iono2d_5 = [1.78, 0.81, 0.64, 0.62, 0.64]

axs[1, 2].plot(iono2d_eps, iono2d_1, label="ε=0.50", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[1, 2].plot(iono2d_eps, iono2d_2, label="ε=0.75", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[1, 2].plot(iono2d_eps, iono2d_3, label="ε=1.00", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[1, 2].plot(iono2d_eps, iono2d_4, label="ε=1.25", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
axs[1, 2].plot(iono2d_eps, iono2d_5, label="ε=1.50", color='#6ab04c', marker='p',
         linewidth=1, markersize=4, markerfacecolor='#6ab04c')
   
axs[1, 2].set_ylabel("Execution Time (s)")
axs[1, 2].set_xlabel(r'$r$', fontsize=16)
axs[1, 2].set_xscale('linear')
axs[1, 2].set_yscale('log')
axs[1, 2].set_xticks(iono2d_eps)
axs[1, 2].set_ylim(0, 10)
axs[1, 2].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[1, 2].set_title("(g) IONO")
axs[1, 2].legend();

# PORTO DATASET
porto_eps = [20, 40, 60, 80, 100]
porto_1 = [0.7, 0.54, 0.56, 0.47, 0.51]
porto_2 = [0.52, 0.38, 0.32, 0.33, 0.37]
porto_3 = [0.4, 0.3, 0.24, 0.39, 0.25]
porto_4 = [0.31, 0.23, 0.23, 0.23, 0.25]
porto_5 = [0.22, 0.22, 0.22, 0.24, 0.24]

axs[1, 3].plot(porto_eps, porto_1, label="ε=0.002", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[1, 3].plot(porto_eps, porto_2, label="ε=0.004", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[1, 3].plot(porto_eps, porto_3, label="ε=0.006", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[1, 3].plot(porto_eps, porto_4, label="ε=0.008", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
axs[1, 3].plot(porto_eps, porto_5, label="ε=0.010", color='#6ab04c', marker='p',
         linewidth=1, markersize=4, markerfacecolor='#6ab04c')
   
axs[1, 3].set_ylabel("Execution Time (s)")
axs[1, 3].set_xlabel(r'$r$', fontsize=16)
axs[1, 3].set_xscale('linear')
axs[1, 3].set_yscale('log')
axs[1, 3].set_xticks(porto_eps)
axs[1, 3].set_ylim(0.1, 10)
axs[1, 3].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[1, 3].set_title("(h) PORTO")
axs[1, 3].legend();

######################################################################################
figname = '2d_partition_selection_experiment'
plt.savefig(figname+'.png', bbox_inches='tight', dpi=600)
plt.show()
# Out:
# <ipython-input-3-14535cb0e585>:154: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   axs[1, 0].set_ylim(0, 10)
# <ipython-input-3-14535cb0e585>:212: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   axs[1, 2].set_ylim(0, 10)
