# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker

# %%
plt.rcParams.update({'font.size': 14, 'axes.titlesize': 14,'legend.loc': 'upper center', 'legend.fontsize': 14})

fig, axs = plt.subplots(3, 4, figsize=(16, 9), dpi=800)
fig.tight_layout(h_pad=3.0, w_pad=3.0)
fig.patch.set_facecolor('white')

##############################################################################
########################## EPS EXPERIMENT
#############################################################################
# NGSIM DATASET
ngsi_eps = [0.5, 0.75, 1, 1.25, 1.5]
ngsi_indexing_dbscan_runtime_eps = [1.34, 0.82, 0.6, 0.41, 0.33]
ngsi_gdbscan_runtime_eps = [8.82, 5.01, 4.16, 3.21, 2.62]
ngsi_dclust_runtime_eps = [8.28, 5.63, 4.33, 3.36, 2.78]
ngsi_mcpu_runtime_eps = [98.34, 121.62, 131.44, 139.19, 144.2]

axs[0, 0].plot(ngsi_eps, ngsi_indexing_dbscan_runtime_eps, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[0, 0].plot(ngsi_eps, ngsi_gdbscan_runtime_eps, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[0, 0].plot(ngsi_eps, ngsi_dclust_runtime_eps, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[0, 0].plot(ngsi_eps, ngsi_mcpu_runtime_eps, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')

axs[0, 0].set_ylabel("Execution Time (s)")
axs[0, 0].set_xlabel("ε")
axs[0, 0].set_xscale('linear')
axs[0, 0].set_yscale('log')
axs[0, 0].set_xticks(ngsi_eps)
axs[0, 0].set_ylim(0.1, 1000)
axs[0, 0].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[0, 0].set_title("(a) NGSIM")

# SPATIAL DATASET
spatial_eps = [0.002, 0.004, 0.006, 0.008, 0.01]
spatial_indexing_dbscan_runtime_eps = [2.1, 1.03, 0.55, 0.42, 0.32]
spatial_gdbscan_runtime_eps = [11.36, 9.77, 7.09, 5.27, 4.27]
spatial_dclust_runtime_eps = [37.45, 22.07, 12.23, 8.53, 6.92]
spatial_mcpu_runtime_eps = [183.78, 160.55, 160.4, 161.43, 163.3]

axs[0, 1].plot(spatial_eps, spatial_indexing_dbscan_runtime_eps, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[0, 1].plot(spatial_eps, spatial_gdbscan_runtime_eps, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[0, 1].plot(spatial_eps, spatial_dclust_runtime_eps, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[0, 1].plot(spatial_eps, spatial_mcpu_runtime_eps, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
   
axs[0, 1].set_ylabel("Execution Time (s)")
axs[0, 1].set_xlabel("ε")
axs[0, 1].set_xscale('linear')
axs[0, 1].set_yscale('log')
axs[0, 1].set_xticks(spatial_eps)
axs[0, 1].set_ylim(0.1, 1000)
axs[0, 1].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[0, 1].set_title("(b) SPATIAL")

# IONO 2D
iono2d_eps = [0.5, 0.75, 1.0, 1.25, 1.5]
iono2d_indexing_dbscan_runtime_eps = [1.4, 1.01, 0.87, 0.76, 0.64]
iono2d_gdbscan_runtime_eps = [5.33, 4.23, 3.77, 3.37, 3.5]
iono2d_dclust_runtime_eps = [23.85, 21.53, 18.27, 15.22, 13.58]
iono2d_mcpu_runtime_eps = [149.43, 148.85, 150.9, 153.06, 155.63]

axs[0, 2].plot(iono2d_eps, iono2d_indexing_dbscan_runtime_eps, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[0, 2].plot(iono2d_eps, iono2d_gdbscan_runtime_eps, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[0, 2].plot(iono2d_eps, iono2d_dclust_runtime_eps, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[0, 2].plot(iono2d_eps, iono2d_mcpu_runtime_eps, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
   
axs[0, 2].set_ylabel("Execution Time (s)")
axs[0, 2].set_xlabel("ε")
axs[0, 2].set_xscale('linear')
axs[0, 2].set_yscale('log')
axs[0, 2].set_xticks(iono2d_eps)
axs[0, 2].set_ylim(0.1, 1000)
axs[0, 2].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[0, 2].set_title("(c) IONO")

# PORTO
porto_eps = [0.002, 0.004, 0.006, 0.008, 0.01]
porto_indexing_dbscan_runtime_eps = [0.5, 0.35, 0.26, 0.22, 0.22]
porto_gdbscan_runtime_eps = [1.09, 0.67, 0.74, 0.67, 0.86]
porto_dclust_runtime_eps = [3.59, 2.69, 2.94, 2.43, 1.88]
porto_mcpu_runtime_eps = [31.8, 29.38, 34.13, 39.29, 43.57]

axs[0, 3].plot(porto_eps, porto_indexing_dbscan_runtime_eps, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[0, 3].plot(porto_eps, porto_gdbscan_runtime_eps, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[0, 3].plot(porto_eps, porto_dclust_runtime_eps, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[0, 3].plot(porto_eps, porto_mcpu_runtime_eps, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
   
axs[0, 3].set_ylabel("Execution Time (s)")
axs[0, 3].set_xlabel("ε")
axs[0, 3].set_xscale('linear')
axs[0, 3].set_yscale('log')
axs[0, 3].set_xticks(porto_eps)
axs[0, 3].set_ylim(0.1, 1000)
axs[0, 3].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[0, 3].set_title("(d) PORTO")


##############################################################################
########################## MINPTS EXPERIMENT
#############################################################################

# NGSIM DATASET
ngsi_minpts = [4, 8, 16, 32, 64]
ngsi_indexing_dbscan_runtime_minpts = [0.33, 0.41, 0.69, 0.9, 1.61]
ngsi_gdbscan_runtime_minpts = [3.3, 3.21, 2.83, 2.55, 2.66]
ngsi_dclust_runtime_minpts = [1.95, 3.62, 4.58, 6.37, 11.19]
ngsi_mcpu_runtime_minpts = [144.7, 139.19, 129.17, 114.8, 78]

axs[1, 0].plot(ngsi_minpts, ngsi_indexing_dbscan_runtime_minpts, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[1, 0].plot(ngsi_minpts, ngsi_gdbscan_runtime_minpts, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[1, 0].plot(ngsi_minpts, ngsi_dclust_runtime_minpts, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[1, 0].plot(ngsi_minpts, ngsi_mcpu_runtime_minpts, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')


axs[1, 0].set_ylabel("Execution Time (s)")
axs[1, 0].set_xlabel("minPts")
axs[1, 0].set_xscale('log')
axs[1, 0].set_yscale('log')
axs[1, 0].set_xticks(ngsi_minpts)
axs[1, 0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axs[1, 0].set_ylim(0.1, 1000)
axs[1, 0].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[1, 0].set_title("(e) NGSIM")

# SPATIAL DATASET
spatial_minpts = [4, 8, 16, 32, 64]
spatial_indexing_dbscan_runtime_minpts = [0.38, 0.35, 0.4, 0.57, 1.14]
spatial_gdbscan_runtime_minpts = [8.64, 5.27, 4.4, 3.29, 2.26]
spatial_dclust_runtime_minpts = [9.37, 9.32, 10.85, 13.28, 28.52]
spatial_mcpu_runtime_minpts = [167.9, 161.4, 160.2, 160.2, 160.3]

axs[1, 1].plot(spatial_minpts, spatial_indexing_dbscan_runtime_minpts, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[1, 1].plot(spatial_minpts, spatial_gdbscan_runtime_minpts, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[1, 1].plot(spatial_minpts, spatial_dclust_runtime_minpts, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[1, 1].plot(spatial_minpts, spatial_mcpu_runtime_minpts, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')

   
axs[1, 1].set_ylabel("Execution Time (s)")
axs[1, 1].set_xlabel("minPts")
axs[1, 1].set_xscale('log')
axs[1, 1].set_yscale('log')
axs[1, 1].set_xticks(spatial_minpts)
axs[1, 1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axs[1, 1].set_ylim(0.1, 1000)
axs[1, 1].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[1, 1].set_title("(f) SPATIAL")

# IONO 2D
iono2d_minpts = [4, 8, 16, 32, 64]
iono2d_indexing_dbscan_runtime_minpts = [0.64, 0.66, 0.65, 0.68, 0.65]
iono2d_gdbscan_runtime_minpts = [3.5, 3.17, 3.1, 3.02, 2.41]
iono2d_dclust_runtime_minpts = [13.31, 15.54, 13.9, 15.5, 13.15]
iono2d_mcpu_runtime_minpts = [156.11, 159.4, 158.5, 156.95, 149.2]

axs[1, 2].plot(iono2d_minpts, iono2d_indexing_dbscan_runtime_minpts, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[1, 2].plot(iono2d_minpts, iono2d_gdbscan_runtime_minpts, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[1, 2].plot(iono2d_minpts, iono2d_dclust_runtime_minpts, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[1, 2].plot(iono2d_minpts, iono2d_mcpu_runtime_minpts, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
   
axs[1, 2].set_ylabel("Execution Time (s)")
axs[1, 2].set_xlabel("minPts")
axs[1, 2].set_xscale('log')
axs[1, 2].set_yscale('log')
axs[1, 2].set_xticks(iono2d_minpts)
axs[1, 2].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axs[1, 2].set_ylim(0.1, 1000)
axs[1, 2].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[1, 2].set_title("(g) IONO")

# PORTO
porto_minpts = [4, 8, 16, 32, 64]
porto_indexing_dbscan_runtime_minpts = [0.25, 0.23, 0.25, 0.25, 0.23]
porto_gdbscan_runtime_minpts = [0.91, 0.68, 0.68, 0.65, 0.65]
porto_dclust_runtime_minpts = [3.43, 2.25, 1.92, 1.9, 2.16]
porto_mcpu_runtime_minpts = [39.29, 39.27, 38.2, 39.12, 38.86]

axs[1, 3].plot(porto_minpts, porto_indexing_dbscan_runtime_minpts, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[1, 3].plot(porto_minpts, porto_gdbscan_runtime_minpts, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[1, 3].plot(porto_minpts, porto_dclust_runtime_minpts, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[1, 3].plot(porto_minpts, porto_mcpu_runtime_minpts, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
   
axs[1, 3].set_ylabel("Execution Time (s)")
axs[1, 3].set_xlabel("minPts")
axs[1, 3].set_xscale('log')
axs[1, 3].set_yscale('log')
axs[1, 3].set_xticks(porto_minpts)
axs[1, 3].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axs[1, 3].set_ylim(0.1, 1000)
axs[1, 3].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[1, 3].set_title("(h) PORTO")


##############################################################################
########################## POINTS EXPERIMENT
#############################################################################

# NGSIM DATASET
ngsi_points = [50000, 100000, 200000, 400000, 800000]
ngsi_indexing_dbscan_runtime_points = [0.3, 0.32, 0.37, 0.41, 0.64]
ngsi_gdbscan_runtime_points = [0.33, 0.43, 1.34, 3.21, None]
ngsi_dclust_runtime_points = [1.35, 1.96, 2.52, 3.36, 5.32]
ngsi_mcpu_runtime_points = [1.58, 7.64, 33.51, 138.41, 788.12]

axs[2, 0].plot(ngsi_points, ngsi_indexing_dbscan_runtime_points, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[2, 0].plot(ngsi_points, ngsi_gdbscan_runtime_points, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[2, 0].plot(ngsi_points, ngsi_dclust_runtime_points, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[2, 0].plot(ngsi_points, ngsi_mcpu_runtime_points, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')

axs[2, 0].set_ylabel("Execution Time (s)")
axs[2, 0].set_xlabel(r'$|D|$')
axs[2, 0].set_xscale('log')
axs[2, 0].set_yscale('log')
axs[2, 0].set_xticks(ngsi_points)
axs[2, 0].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axs[2, 0].set_ylim(0.1, 1000)
axs[2, 0].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[2, 0].set_title("(i) NGSIM")
axs[2, 0].ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# SPATIAL DATASET
spatial_points = [25000, 50000, 100000, 200000, 400000]
spatial_indexing_dbscan_runtime_points = [0.22, 0.32, 0.36, 0.4, 0.41]
spatial_gdbscan_runtime_points = [0.24, 0.4, 0.62, 1.75, 5.23]
spatial_dclust_runtime_points = [1.85, 3.15, 4.8, 7.12, 8.53]
spatial_mcpu_runtime_points = [0.3, 0.97, 2.56, 9.2, 161.29]

axs[2, 1].plot(spatial_points, spatial_indexing_dbscan_runtime_points, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[2, 1].plot(spatial_points, spatial_gdbscan_runtime_points, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[2, 1].plot(spatial_points, spatial_dclust_runtime_points, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[2, 1].plot(spatial_points, spatial_mcpu_runtime_points, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
   
axs[2, 1].set_ylabel("Execution Time (s)")
axs[2, 1].set_xlabel(r'$|D|$')
axs[2, 1].set_xscale('log')
axs[2, 1].set_yscale('log')
axs[2, 1].set_xticks(spatial_points)
axs[2, 1].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axs[2, 1].set_ylim(0.01, 1000)
axs[2, 1].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[2, 1].set_title("(j) SPATIAL")
axs[2, 1].ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# IONO 2D
iono2d_points = [50000, 100000, 200000, 400000, 800000]
iono2d_indexing_dbscan_runtime_points = [0.2, 0.31, 0.48, 0.64, 0.92]
iono2d_gdbscan_runtime_points = [0.4, 0.69, 1.09, 3.5, None]
iono2d_dclust_runtime_points = [2.6, 5.91, 7.52, 17.77, 27.04]
iono2d_mcpu_runtime_points = [10.92, 41.03, 159.28, 184.78, 1760.93]

axs[2, 2].plot(iono2d_points, iono2d_indexing_dbscan_runtime_points, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[2, 2].plot(iono2d_points, iono2d_gdbscan_runtime_points, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[2, 2].plot(iono2d_points, iono2d_dclust_runtime_points, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[2, 2].plot(iono2d_points, iono2d_mcpu_runtime_points, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
   
axs[2, 2].set_ylabel("Execution Time (s)")
axs[2, 2].set_xlabel(r'$|D|$')
axs[2, 2].set_xscale('log')
axs[2, 2].set_yscale('log')
axs[2, 2].set_xticks(iono2d_points)
axs[2, 2].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axs[2, 2].set_ylim(0.1, 10000)
axs[2, 2].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[2, 2].set_title("(k) IONO")
axs[2, 2].ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# PORTO
porto_points = [40000, 80000, 160000, 320000, 640000]
porto_indexing_dbscan_runtime_points = [None, 0.16, 0.24, 0.85, 2.53]
porto_gdbscan_runtime_points = [0.1, 0.28, 0.67, None, None]
porto_dclust_runtime_points = [None, 1.21, 1.64, 4.97, 26.06]
porto_mcpu_runtime_points = [2.57, 10.2, 39.25, 156.6, 752.33]

axs[2, 3].plot(porto_points, porto_indexing_dbscan_runtime_points, label="CUDA-DClust+", color='#130f40', marker='D',
         linewidth=1, markersize=4, markerfacecolor='#130f40')
axs[2, 3].plot(porto_points, porto_gdbscan_runtime_points, label="G-DBSCAN", color='#27ae60', marker='o',
         linewidth=1, markersize=4, markerfacecolor='#27ae60')
axs[2, 3].plot(porto_points, porto_dclust_runtime_points, label="CUDA-DClust", color='#c0392b', marker='v',
         linewidth=1, markersize=4, markerfacecolor='#c0392b')
axs[2, 3].plot(porto_points, porto_mcpu_runtime_points, label="CPU-DBSCAN", color='#4834d4', marker='x',
         linewidth=1, markersize=4, markerfacecolor='#4834d4')
   
axs[2, 3].set_ylabel("Execution Time (s)")
axs[2, 3].set_xlabel(r'$|D|$')
axs[2, 3].set_xscale('log')
axs[2, 3].set_yscale('log')
axs[2, 3].set_xticks(porto_points)
axs[2, 3].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axs[2, 3].set_ylim(0.01, 10000)
axs[2, 3].yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda y, _: '{:g}'.format(y)))
axs[2, 3].set_title("(l) PORTO")
axs[2, 3].ticklabel_format(style='sci', axis='x', scilimits=(0,0))

######################################################################################
plt.subplots_adjust(top=0.9, bottom=0.1)

handles, labels = axs[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, ncol=5, labelspacing=16)

figname = '2d_all_experiments'
plt.savefig(figname+'.png', bbox_inches='tight', dpi=600)
plt.show()
